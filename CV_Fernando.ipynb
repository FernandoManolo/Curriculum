# %% [markdown]
# <h1>Fernando Henrique Pedroso Gentil</h1>
#
# *1994, Rua Osíris Magalhães de Almeida, Jd Kemel.*<br/>
# *São Paulo – SP – Brazil, Cep: 03178-200* <br/>
# fhpg_1994@yahoo.com.br

# %% [markdown]
# ---

# %% [markdown]
# <h2>Objective</h2>

# %% [markdown]
# Work as a Intern/Jr. in Data Science/Data Analysis

# %% [markdown]
# ---

# %% [markdown]
# <h2>Resume</h2>

# %% [markdown]
# Im a Support Analyst with a programming college background who love work with data to create information. I have a miscellaneous
# background, since i have worked in a water distribution company, a bank, hospital, etc. so i can see how data can improve processes and show a better place to put investiments. I always believe in a phrase "Information is the best currency".
#
# Down here you can view a WordClouds with my certificates

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# ---

# %% [markdown]
# <h2>Experience</h2>

# %% [markdown]
# <b>Support Analyst </b><br/>
# *Núcleo Hospitalar de Barueri*<br/>
# *Sep 2016 - Dec 2017*<br/>
#
# <b>Test Analyst</b><br/>
# *Assurance IT*<br/>
# *Mar 2016 - Sep 2016*
#
# <b>Trainee</b><br/>
# *Bradesco Seguros & Previdência*<br/>
# *Jun 2012 - Oct 2013*
#
# <b>Intern</b><br/>
# *Sabesp*
# *Aug 2010 - Nov 2010*

# %% [markdown]
# ---

# %% [markdown]
# <h1>Formação Acadêmica</h1>

# %% [markdown]
# <b>Systems Analysis and Development.</b><br/>
# *FIAP - São Paulo - Brazil*<br/>
# *Jun 2012 - Oct 2013*

# %% [markdown]
# <b>English.</b><br/>
# *IEA - Dublin - Ireland*<br/>
# *Jan 2014 - Jan 2015*

# %% [markdown]
# ---

# %% [markdown]
# <h1>Languages</h1>

# %% [markdown]
# <b>English</b><br/>
# *Advanced/Fluent*

# %% [markdown]
# <b>Portuguese</b><br/>
# *Native/Fluent*

# %% [markdown]
# ---

# %% [markdown]
# <h1>Certificates</h1><br/>

# %%
# The code was removed by Watson Studio for sharing.

# %%
# The code was removed by Watson Studio for sharing.

# %%
myd.sort_values(by=['Empresa'])
# Out:
#                                                Cursos          Empresa
# 11                         Data Analysis with Python   Cognitive Class
# 16                    Digital Analytics & Regression   Cognitive Class
# 15                          Data Privacy Fundamentals  Cognitive Class
# 13                       Machine Learning with Python  Cognitive Class
# 7        Data Science Hands-On with Open Source Tools  Cognitive Class
# 8                       Introduction to Data Science   Cognitive Class
# 9                            Data Science Methodology  Cognitive Class
# 10                        Python 101 for Data Science  Cognitive Class
# 12                    Data Visualization with Python   Cognitive Class
# 21                         Data Analysis with Python          Coursera
# 20                           Data Science Orientation         Coursera
# 19                 Open Source Tools for Data Science         Coursera
# 23                    Python for Applied Data Science         Coursera
# 22                 Databases and SQL for Data Science         Coursera
# 1   Qualification Certificate in Web 2.0 Developer...             FIAP
# 0   Professional Qualification Certificate in Syst...             FIAP
# 6              Machine Learning with Python – Level 1              IBM
# 14                 Predictive Modeling Fundamentals I              IBM
# 5                             Python for Data Science              IBM
# 4          Applied Data Science with Python - Level 2              IBM
# 17               Data Science for Business - Level 1               IBM
# 18               Data Science for Business - Level 2               IBM
# 3             Data Science Foundations - Level 2 (V2)              IBM
# 2                 Data Science Foundations - Level 1               IBM
