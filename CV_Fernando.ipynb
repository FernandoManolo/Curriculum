# %% [markdown]
# <h1>Fernando Henrique Pedroso Gentil</h1>
#
# *1994, Rua Osíris Magalhães de Almeida, Jd Kemel.*<br/>
# *São Paulo – SP – Brazil, Cep: 03178-200* <br/>
# fhpg_1994@yahoo.com.br

# %% [markdown]
# ---

# %% [markdown]
# <h2>Objective</h2>

# %% [markdown]
# Work as a Intern/Jr. in Data Science/Data Analysis

# %% [markdown]
# ---

# %% [markdown]
# <h2>Resume</h2>

# %% [markdown]
# Im a Support Analyst with a programming college background who love work with data to create information. I have a miscellaneous
# background, since i has worked in a water distribution company, a bank, hospital, etc. so i can see how data can improve processes and show a better place to put investiments. I always believe in a phrase "Information is the best currency".
#
# Down here you can view a WordClouds with my certificates

# %%
# !conda install -c conda-forge wordcloud==1.4.1 --yes;
# !pip install xlrd

# %%
import ibm_boto3
from botocore.client import Config
import json
import pandas as pd
import numpy as np 
from PIL import Image 
# %matplotlib inline
from wordcloud import WordCloud, STOPWORDS;
import matplotlib as mpl
import matplotlib.pyplot as plt
import io

# %%
# The code was removed by Watson Studio for sharing.

# %%
text = streaming_body_2.read().decode('UTF-8')

# %%
stopwords = set(STOPWORDS)
stopwords.add('Level')
course_wc = WordCloud(background_color='white',stopwords=stopwords)
course_wc.generate(text)

fig = plt.figure()
fig.set_figwidth(14) 
fig.set_figheight(20)

plt.imshow(course_wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# <h2>Experience</h2>

# %% [markdown]
# <b>Support Analyst </b><br/>
# *Núcleo Hospitalar de Barueri*<br/>
# *Sep 2016 - Dec 2017*<br/>
#
# <b>Test Analyst</b><br/>
# *Assurance IT*<br/>
# *Mar 2016 - Sep 2016*
#
# <b>Trainee</b><br/>
# *Bradesco Seguros & Previdência*<br/>
# *Jun 2012 - Oct 2013*
#
# <b>Intern</b><br/>
# *Sabesp*
# *Aug 2010 - Nov 2010*

# %% [markdown]
# ---

# %% [markdown]
# <h1>Academic Formation</h1>

# %% [markdown]
# <b>Systems Analysis and Development.</b><br/>
# *FIAP - São Paulo - Brazil*<br/>
# *Jun 2012 - Oct 2013*

# %% [markdown]
# <b>English.</b><br/>
# *IEA - Dublin - Ireland*<br/>
# *Jan 2014 - Jan 2015*

# %% [markdown]
# ---

# %% [markdown]
# <h1>Languages</h1>

# %% [markdown]
# <b>English</b><br/>
# *Advanced/Fluent*

# %% [markdown]
# <b>Portuguese</b><br/>
# *Native/Fluent*

# %% [markdown]
# ---

# %% [markdown]
# <h1>Certificates</h1><br/>

# %%
# The code was removed by Watson Studio for sharing.

# %%
xls_file = pd.ExcelFile(streaming_body_3) #create instance of ExcelFile class
myd = xls_file.parse('Planilha1') #read the data from selected Excel sheet

# %%
myd = myd.rename(columns={'Empresa' : 'By', 'Cursos' : 'Certificates'})

# %%
myd.set_index('By')

# %%
df_ibm = myd.loc[(myd['By'] == 'IBM')]
df_coursera = myd.loc[(myd['By'] == 'Coursera')]
df_cognitive = myd.loc[(myd['By'] == 'Cognitive Class')]

# %%
from IPython.display import display,HTML

def multi_column_df_display(list_dfs, cols=3):
    html_table = "<table style='width:100%; border:0px'>{content}</table>"
    html_row = "<tr style='border:0px'>{content}</tr>"
    html_cell = "<td style='width:{width}%;vertical-align:top;border:0px'>{{content}}</td>"
    html_cell = html_cell.format(width=100/cols)

    cells = [ html_cell.format(content=df.to_html()) for df in list_dfs ]
    cells += (cols - (len(list_dfs)%cols)) * [html_cell.format(content="")] # pad
    rows = [ html_row.format(content="".join(cells[i:i+cols])) for i in range(0,len(cells),cols)]
    display(HTML(html_table.format(content="".join(rows))))

# %%
list_dfs = []
list_dfs.append(df_ibm)
list_dfs.append(df_coursera)
list_dfs.append(df_cognitive)
multi_column_df_display(list_dfs)
# Out:
# <table style='width:100%; border:0px'><tr style='border:0px'><td style='width:33.333333333333336%;vertical-align:top;border:0px'><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Certificates</th>
#       <th>By</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>Data Science Foundations - Level 1</td>
#       <td>IBM</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Data Science Foundations - Level 2 (V2)</td>
#       <td>IBM</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Applied Data Science with Python - Level 2</td>
#       <td>IBM</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Python for Data Science</td>
#       <td>IBM</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Machine Learning with Python – Level 1</td>
#       <td>IBM</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Predictive Modeling Fundamentals I</td>
# ...
